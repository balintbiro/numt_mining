# %% [markdown]
# gdna informations https://ftp.ncbi.nlm.nih.gov/genomes/GENOME_REPORTS/eukaryotes.txt
#
# mtdna informations https://www.ncbi.nlm.nih.gov/genome/browse#!/organelles/organelles.csv

# %%
#importing required modules
import os
import numpy as np
import scipy.stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#get nuclear genome informations
gdnas=pd.read_csv('../data/eukaryotes.txt',sep='\t',index_col=0)
gdnas.head(n=2)
# Out:
#                              TaxID BioProject Accession  BioProject ID  \
# #Organism/Name
# Neopyropia yezoensis          2788          PRJNA589917         589917
# Emiliania huxleyi CCMP1516  280463           PRJNA77753          77753
#
#                                Group        SubGroup  Size (Mb)      GC%  \
# #Organism/Name
# Neopyropia yezoensis           Other           Other    107.591  64.8454
# Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
#
#                            Assembly Accession  \
# #Organism/Name
# Neopyropia yezoensis          GCA_009829735.1
# Emiliania huxleyi CCMP1516    GCA_000372725.1
#
#                                                                     Replicons  \
# #Organism/Name
# Neopyropia yezoensis        chromosome 1:CM020618.1; chromosome 2:CM020619...
# Emiliania huxleyi CCMP1516                                                  -
#
#                                WGS  Scaffolds  Genes Proteins Release Date  \
# #Organism/Name
# Neopyropia yezoensis        WMLA01         28      -        -   2020/01/03
# Emiliania huxleyi CCMP1516  AHAL01       7795  38549    38554   2013/04/19
#
#                            Modify Date      Status            Center  \
# #Organism/Name
# Neopyropia yezoensis        2020/01/06  Chromosome  Ocean University
# Emiliania huxleyi CCMP1516  2014/08/01    Scaffold               JGI
#
#                            BioSample Accession
# #Organism/Name
# Neopyropia yezoensis              SAMN13316713
# Emiliania huxleyi CCMP1516        SAMN02744062

# %%
gdnas.loc[gdnas['BioProject ID']==33554]
# Out:
# Empty DataFrame
# Columns: [TaxID, BioProject Accession, BioProject ID, Group, SubGroup, Size (Mb), GC%, Assembly Accession, Replicons, WGS, Scaffolds, Genes, Proteins, Release Date, Modify Date, Status, Center, BioSample Accession]
# Index: []

# %%
#get mitochondrial genome informations
mtdnas=pd.read_csv('../data/organelles.csv',index_col=0)
mtdnas.head(n=2)
# Out:
#                                                               Organism Groups  \
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...   Eukaryota;Animals;Fishes
# Aacanthocnema dobsoni                               Eukaryota;Animals;Insects
#
#                                                    Strain BioSample  \
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...    NaN       NaN
# Aacanthocnema dobsoni                                 NaN       NaN
#
#                                                      BioProject  Size(Mb)  \
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...  PRJNA353408  0.016581
# Aacanthocnema dobsoni                               PRJNA483618  0.015179
#
#                                                         GC%           Type  \
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...  43.3207  mitochondrion
# Aacanthocnema dobsoni                               21.9382  mitochondrion
#
#                                                                  Replicons  \
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...  NC_031807.1/KU146531.1
# Aacanthocnema dobsoni                               NC_038132.1/MG989216.1
#
#                                                     CDS          Release Date
# #Organism Name
# (Cyprinus carpio 'mirror' x Cyprinus carpio 'si...   13  2016-11-14T00:00:00Z
# Aacanthocnema dobsoni                                13  2018-07-31T00:00:00Z

# %%
#get phylogenetic informations
phylo_data=pd.read_csv('../data/nodes.dmp',sep='\t',header=None)
phylo_data=phylo_data.rename(columns={
    0:'tax_id',
    4:'rank'
                          })
phylo_data.head(n=2)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    tax_id  1       2  3          rank  5    6  7  8  9  ...  16 17  18 19  20  \
# 0       1  |       1  |       no rank  |  NaN  |  8  |  ...   0  |   0  |   0
# 1       2  |  131567  |  superkingdom  |  NaN  |  0  |  ...   0  |   0  |   0
#
#   21  22 23   24 25
# 0  |   0  |  NaN  |
# 1  |   0  |  NaN  |
#
# [2 rows x 26 columns]

# %%
#add phylogenetic rank to gdnas based on tax_id
def add_phylo_rank(tax_id):
    try:
        rank=phylo_data.loc[phylo_data['tax_id']==tax_id]['rank'].tolist()[0]
        return rank
    except:
        return np.nan

ranks=gdnas['TaxID'].apply(add_phylo_rank)
gdnas['rank']=ranks
gdnas.head(n=2)
# Out:
#                              TaxID BioProject Accession  BioProject ID  \
# #Organism/Name
# Neopyropia yezoensis          2788          PRJNA589917         589917
# Emiliania huxleyi CCMP1516  280463           PRJNA77753          77753
#
#                                Group        SubGroup  Size (Mb)      GC%  \
# #Organism/Name
# Neopyropia yezoensis           Other           Other    107.591  64.8454
# Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
#
#                            Assembly Accession  \
# #Organism/Name
# Neopyropia yezoensis          GCA_009829735.1
# Emiliania huxleyi CCMP1516    GCA_000372725.1
#
#                                                                     Replicons  \
# #Organism/Name
# Neopyropia yezoensis        chromosome 1:CM020618.1; chromosome 2:CM020619...
# Emiliania huxleyi CCMP1516                                                  -
#
#                                WGS  Scaffolds  Genes Proteins Release Date  \
# #Organism/Name
# Neopyropia yezoensis        WMLA01         28      -        -   2020/01/03
# Emiliania huxleyi CCMP1516  AHAL01       7795  38549    38554   2013/04/19
#
#                            Modify Date      Status            Center  \
# #Organism/Name
# Neopyropia yezoensis        2020/01/06  Chromosome  Ocean University
# Emiliania huxleyi CCMP1516  2014/08/01    Scaffold               JGI
#
#                            BioSample Accession     rank
# #Organism/Name
# Neopyropia yezoensis              SAMN13316713  species
# Emiliania huxleyi CCMP1516        SAMN02744062   strain

# %%
#function for adding mtdna size to gdnas
def get_mt_size(gdna_row):
    mtdna=mtdnas.loc[mtdnas['BioProject']==gdna_row['BioProject Accession']]
    try:
        return mtdna['Size(Mb)'].tolist()[0]
    except:
        return np.nan
    
mt_dna_sizes=gdnas.apply(get_mt_size, axis=1)

# %%
#add mtdna size to gdna df
gdnas['mt_dna_size(Mb)']=mt_dna_sizes
gdnas.head(n=2)
# Out:
#                              TaxID BioProject Accession  BioProject ID  \
# #Organism/Name
# Neopyropia yezoensis          2788          PRJNA589917         589917
# Emiliania huxleyi CCMP1516  280463           PRJNA77753          77753
#
#                                Group        SubGroup  Size (Mb)      GC%  \
# #Organism/Name
# Neopyropia yezoensis           Other           Other    107.591  64.8454
# Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
#
#                            Assembly Accession  \
# #Organism/Name
# Neopyropia yezoensis          GCA_009829735.1
# Emiliania huxleyi CCMP1516    GCA_000372725.1
#
#                                                                     Replicons  \
# #Organism/Name
# Neopyropia yezoensis        chromosome 1:CM020618.1; chromosome 2:CM020619...
# Emiliania huxleyi CCMP1516                                                  -
#
#                                WGS  Scaffolds  Genes Proteins Release Date  \
# #Organism/Name
# Neopyropia yezoensis        WMLA01         28      -        -   2020/01/03
# Emiliania huxleyi CCMP1516  AHAL01       7795  38549    38554   2013/04/19
#
#                            Modify Date      Status            Center  \
# #Organism/Name
# Neopyropia yezoensis        2020/01/06  Chromosome  Ocean University
# Emiliania huxleyi CCMP1516  2014/08/01    Scaffold               JGI
#
#                            BioSample Accession     rank  mt_dna_size(Mb)
# #Organism/Name
# Neopyropia yezoensis              SAMN13316713  species              NaN
# Emiliania huxleyi CCMP1516        SAMN02744062   strain              NaN

# %%
#drop rows where no data for genome sizes
gdnas=gdnas.dropna(subset=['Size (Mb)','mt_dna_size(Mb)'])
gdnas.head(n=2)
# Out:
#                      TaxID BioProject Accession  BioProject ID   Group  \
# #Organism/Name
# Medicago truncatula   3880          PRJNA702529         702529  Plants
# Triticum aestivum     4565          PRJNA764258         764258  Plants
#
#                         SubGroup  Size (Mb)      GC% Assembly Accession  \
# #Organism/Name
# Medicago truncatula  Land Plants    430.008  33.4462    GCA_003473485.2
# Triticum aestivum    Land Plants  14567.000   46.215    GCA_018294505.1
#
#                                                              Replicons  \
# #Organism/Name
# Medicago truncatula  chromosome 1:NC_053042.1/CM010648.1; chromosom...
# Triticum aestivum    chromosome 1A:NC_057794.1/CM031178.1; chromoso...
#
#                           WGS  Scaffolds   Genes Proteins Release Date  \
# #Organism/Name
# Medicago truncatula    PSQE01         42   39589    42683   2018/09/06
# Triticum aestivum    JAGHKL01      91589  155463   142442   2021/05/06
#
#                     Modify Date      Status Center BioSample Accession  \
# #Organism/Name
# Medicago truncatula  2018/09/12  Chromosome   NCBI        SAMN08400029
# Triticum aestivum    2021/05/06  Chromosome   NCBI        SAMN16451473
#
#                         rank  mt_dna_size(Mb)
# #Organism/Name
# Medicago truncatula  species         0.124033
# Triticum aestivum    species         0.452526

# %%
#calculate correlation WITHOUT genome quality control
plt.style.use('seaborn')
title=scipy.stats.spearmanr(gdnas['Size (Mb)'],gdnas['mt_dna_size(Mb)'])[0]
fig,axs=plt.subplots()
axs.scatter(np.log(gdnas['Size (Mb)']),np.log(gdnas['mt_dna_size(Mb)']),edgecolors='black',s=200,alpha=.25)
plt.title(f'Spearman correlation: {str(round(title,2))}')
m, b = np.polyfit(np.log(gdnas['Size (Mb)']),np.log(gdnas['mt_dna_size(Mb)']), 1)
axs.plot(np.log(gdnas['Size (Mb)']), m*np.log(gdnas['Size (Mb)']) + b,'r')
axs.set_xlabel('gDNA size (Mb)')
axs.set_ylabel('mtDNA size (Mb)')
# Out:
# Text(0, 0.5, 'mtDNA size (Mb)')

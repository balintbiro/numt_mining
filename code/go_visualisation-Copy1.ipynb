# %%
#import modules
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load csv
def get_dfs(filename):
    global indices
    if filename.startswith('.')==False:
        df=pd.read_csv(f'/Volumes/motilin/balint/numt/mice_strains_numt/go_terms/{filename}',header=None,
                       skiprows=1,index_col=0)
        strain=filename.split('_')[0]
        indices.append(strain)
        df.columns=['go_term','go_descritpion']
        df['strain']=len(df)*[strain]
        return df
    else:
        indices.append('empty')

indices=[]
dfs=pd.Series(os.listdir('/Volumes/motilin/balint/numt/mice_strains_numt/go_terms/')).apply(
get_dfs)
dfs.index=indices
dfs
# Out:
# mmfvbnj                             go_term                   ...
# mmdba2j                            go_term                    ...
# mm129s1svimj                                   go_term  \
# 0   ...
# empty                                                        None
# mmc3hhej                                             go_term  ...
# mmnodshiltj                       go_term      go_descritpion ...
# mmpwkphj                          go_term                     ...
# mmbalbcj                          go_term                     ...
# empty                                                        None
# mmnzohlltj                        go_term                     ...
# mmcasteij                         go_term                     ...
# mmc57bl6nj                                      go_term       ...
# mmcbaj                                    go_term  \
# 0        ...
# mmaj                              go_term                     ...
# mmakrj                             go_term                    ...
# mmspretus                         go_term                     ...
# mmlpj                                                       go...
# mm                                                          go...
# mmwsbeij                          go_term                     ...
# dtype: object

# %%
dfs=dfs.drop('empty')

# %%
#merge all the dfs together
merged_df=pd.concat(dfs.tolist())
merged_df
# Out:
#                     go_term  \
# 0
# 1      cell differentiation
# 2      cell differentiation
# 3      cell differentiation
# 4      cell differentiation
# 5      cell differentiation
# ...                     ...
# 15253             transport
# 15254             transport
# 15255             transport
# 15256    biological_process
# 15257    biological_process
#
#                                           go_descritpion    strain
# 0
# 1                                Notch signaling pathway   mmfvbnj
# 2                                   cell differentiation   mmfvbnj
# 3                     multicellular organism development   mmfvbnj
# 4                                      receptor activity   mmfvbnj
# 5                                    calcium ion binding   mmfvbnj
# ...                                                  ...       ...
# 15253  regulation of potassium ion transmembrane tran...  mmwsbeij
# 15254               potassium channel regulator activity  mmwsbeij
# 15255            voltage-gated potassium channel complex  mmwsbeij
# 15256  regulation of potassium ion transmembrane tran...  mmwsbeij
# 15257               potassium channel regulator activity  mmwsbeij
#
# [266932 rows x 3 columns]

# %%
#function for gettin strain spec go terms
def get_strain_spec_go_term_counts(go_term):
    subdf=merged_df.loc[merged_df['go_term']==go_term]
    strain_spec_go_count=[]
    try:
        strains.apply(lambda strain: strain_spec_go_count.append(len(subdf.loc[subdf['strain']==strain])))
    except KeyError:
        strain_spec_go_count.append(0)
    return strain_spec_go_count

# %%
strains=pd.Series(['mm','mmcasteij','mmpwkphj','mmspretus','mmwsbeij','mmfvbnj', 'mmdba2j', 'mm129s1svimj',
                   'mmc3hhej','mmnodshiltj','mmbalbcj', 'mmnzohlltj', 'mmc57bl6nj','mmcbaj', 'mmaj', 'mmakrj',
                   'mmlpj',])
strains
# Out:
# 0               mm
# 1        mmcasteij
# 2         mmpwkphj
# 3        mmspretus
# 4         mmwsbeij
# 5          mmfvbnj
# 6          mmdba2j
# 7     mm129s1svimj
# 8         mmc3hhej
# 9      mmnodshiltj
# 10        mmbalbcj
# 11      mmnzohlltj
# 12      mmc57bl6nj
# 13          mmcbaj
# 14            mmaj
# 15          mmakrj
# 16           mmlpj
# dtype: object

# %%
#get strain spec go terms into a dataframe
go_counts=pd.Series(merged_df['go_term'].unique()).apply(get_strain_spec_go_term_counts)
go_counts.index=merged_df['go_term'].unique()
go_counts=pd.DataFrame(go_counts.tolist())
go_counts.index=merged_df['go_term'].unique()
go_counts.columns=strains
go_counts
# Out:
#                                                      mm  mmcasteij  mmpwkphj  \
# cell differentiation                                604        361       335
# molecular_function                                  778        480       447
# biosynthetic process                                485        324       315
# signal transduction                                 421        299       261
# anatomical structure development                    616        397       372
# ...                                                 ...        ...       ...
# ATPase                                               22          0         0
# DNA metabolic process                                 0          0         0
# biological process involved in symbiotic intera...   67          0         0
# glycosyltransferase activity                         10          0         0
# acyltransferase activity                             23          0         0
#
#                                                     mmspretus  mmwsbeij  \
# cell differentiation                                      329       349
# molecular_function                                        489       481
# biosynthetic process                                      255       325
# signal transduction                                       343       273
# anatomical structure development                          365       383
# ...                                                       ...       ...
# ATPase                                                     12         0
# DNA metabolic process                                      90         0
# biological process involved in symbiotic intera...          0         0
# glycosyltransferase activity                                0         0
# acyltransferase activity                                    0         0
#
#                                                     mmfvbnj  mmdba2j  \
# cell differentiation                                    343      343
# molecular_function                                      473      461
# biosynthetic process                                    325      325
# signal transduction                                     261      261
# anatomical structure development                        393      380
# ...                                                     ...      ...
# ATPase                                                    0        0
# DNA metabolic process                                     0        0
# biological process involved in symbiotic intera...        0        0
# glycosyltransferase activity                              0        0
# acyltransferase activity                                  0        0
#
#                                                     mm129s1svimj  mmc3hhej  \
# cell differentiation                                         332       343
# molecular_function                                           464       473
# biosynthetic process                                         325       325
# signal transduction                                          261       271
# anatomical structure development                             370       380
# ...                                                          ...       ...
# ATPase                                                         0         0
# DNA metabolic process                                          0         0
# biological process involved in symbiotic intera...             0         0
# glycosyltransferase activity                                   0         0
# acyltransferase activity                                       0         0
#
#                                                     mmnodshiltj  mmbalbcj  \
# cell differentiation                                        339       343
# molecular_function                                          456       468
# biosynthetic process                                        319       325
# signal transduction                                         266       261
# anatomical structure development                            367       380
# ...                                                         ...       ...
# ATPase                                                        0         0
# DNA metabolic process                                         0         0
# biological process involved in symbiotic intera...            0         0
# glycosyltransferase activity                                  0         0
# acyltransferase activity                                      0         0
#
#                                                     mmnzohlltj  mmc57bl6nj  \
# cell differentiation                                       343         343
# molecular_function                                         477         473
# biosynthetic process                                       325         325
# signal transduction                                        261         261
# anatomical structure development                           380         380
# ...                                                        ...         ...
# ATPase                                                       0           0
# DNA metabolic process                                        0           0
# biological process involved in symbiotic intera...           0           0
# glycosyltransferase activity                                 0           0
# acyltransferase activity                                     0           0
#
#                                                     mmcbaj  mmaj  mmakrj  \
# cell differentiation                                   340   343     343
# molecular_function                                     459   463     462
# biosynthetic process                                   325   325     325
# signal transduction                                    261   261     261
# anatomical structure development                       377   371     380
# ...                                                    ...   ...     ...
# ATPase                                                   0     0       0
# DNA metabolic process                                    0     0       0
# biological process involved in symbiotic intera...       0     0       0
# glycosyltransferase activity                             0     0       0
# acyltransferase activity                                 0     0       0
#
#                                                     mmlpj
# cell differentiation                                  343
# molecular_function                                    467
# biosynthetic process                                  325
# signal transduction                                   261
# anatomical structure development                      380
# ...                                                   ...
# ATPase                                                  0
# DNA metabolic process                                   0
# biological process involved in symbiotic intera...      0
# glycosyltransferase activity                            0
# acyltransferase activity                                0
#
# [125 rows x 17 columns]

# %%
#https://www.ebi.ac.uk/QuickGO/
biological_process=[
    'cell differentiation',
    'biosynthetic process',
    'signal transduction',
    'anatomical structure development',
    'cellular nitrogen compound metabolic process',
    'cell adhesion',
    'cellular protein modification process',
    'immune system process',
    'cell morphogenesis',
    'cellular component assembly',
    'membrane organization',
    'cytoskeleton organization',
    'protein complex assembly',
    'macromolecular complex assembly',
    'catabolic process',
    'cell proliferation',
    'small molecule metabolic process',
    'protein targeting',
    'nucleocytoplasmic transport',
    'sulfur compound metabolic process',
    'cell death',
    'anatomical structure formation involved in morphogenesis',
    'transport',
    'vesicle-mediated transport',
    'circulatory system process',
    'locomotion',
    'cell motility',
    'embryo development',
    'cell-cell signaling',
    'response to stress',
    'cell cycle',
    'homeostatic process',
    'ribosome biogenesis',
    'transmembrane transport',
    'reproduction',
    'growth',
    'plasma membrane organization',
    'mRNA processing',
    'translation',
    'lipid metabolic process',
    'mitotic cell cycle',
    'developmental maturation',
    'aging',
    'nervous system process',
    'cytoskeleton-dependent intracellular transport',
    'extracellular matrix organization',
    'chromosome organization',
    'tRNA metabolic process',
    'cellular amino acid metabolic process',
    'symbiont process',
    'mitochondrion organization',
    'autophagy',
    'chromosome segregation',
    'mitotic nuclear division',
    'cell division',
    'protein maturation',
    'cell population proliferation',
    'protein-containing complex assembly',
    'protein transport',
    'carbohydrate metabolic process',
    'generation of precursor metabolites and energy',
    'cell junction organization',
    'DNA metabolic process',
    'biological process involved in symbiotic interaction',
    
]
cellular_component=[
    'microtubule organizing center',
    'cytoplasm',
    'intracellular',
    'cell',
    'cytoskeleton',
    'organelle',
    'plasma membrane',
    'nucleoplasm',
    'nucleus',
    'extracellular space',
    'extracellular region',
    'cytoplasmic vesicle',
    'protein complex',
    'nucleolus',
    'Golgi apparatus',
    'endosome',
    'cytosol',
    'endoplasmic reticulum',
    'cilium',
    'nuclear envelope',
    'lipid droplet',
    'mitochondrion',
    'vacuole',
    'lysosome',
    'chromosome',
    'intracellular anatomical structure',
    'protein-containing complex',
    'extracellular matrix',
    'external encapsulating structure',
    
]
molecular_function=[
    'ion binding',
    'phosphatase activity',
    'enzyme regulator activity',
    'enzyme binding',
    'cytoskeletal protein binding',
    'RNA binding',
    'GTPase activity',
    'transferase activity, transferring acyl groups',
    'hydrolase activity, acting on glycosyl bonds',
    'signal transducer activity',
    'hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds',
    'DNA binding',
    'DNA binding transcription factor activity',
    'transcription factor activity, protein binding',
    'transcription factor binding',
    'lipid binding',
    'methyltransferase activity',
    'transferase activity, transferring glycosyl groups',
    'ATPase activity',
    'oxidoreductase activity',
    'ligase activity',
    'kinase activity',
    'transmembrane transporter activity',
    'peptidase activity',
    'DNA-binding transcription factor activity',
    'structural molecule activity',
    'ATPase',
    'glycosyltransferase activity',
    'acyltransferase activity',
    
]

# %%
biological_process_gos=go_counts.loc[biological_process]
cellular_component_gos=go_counts.loc[cellular_component]
molecular_function_gos=go_counts.loc[molecular_function]

# %%
biological_process_gos.index.values
# Out:
# array(['cell differentiation', 'biosynthetic process',
#        'signal transduction', 'anatomical structure development',
#        'cellular nitrogen compound metabolic process', 'cell adhesion',
#        'cellular protein modification process', 'immune system process',
#        'cell morphogenesis', 'cellular component assembly',
#        'membrane organization', 'cytoskeleton organization',
#        'protein complex assembly', 'macromolecular complex assembly',
#        'catabolic process', 'cell proliferation',
#        'small molecule metabolic process', 'protein targeting',
#        'nucleocytoplasmic transport', 'sulfur compound metabolic process',
#        'cell death',
#        'anatomical structure formation involved in morphogenesis',
#        'transport', 'vesicle-mediated transport',
#        'circulatory system process', 'locomotion', 'cell motility',
#        'embryo development', 'cell-cell signaling', 'response to stress',
#        'cell cycle', 'homeostatic process', 'ribosome biogenesis',
#        'transmembrane transport', 'reproduction', 'growth',
#        'plasma membrane organization', 'mRNA processing', 'translation',
#        'lipid metabolic process', 'mitotic cell cycle',
#        'developmental maturation', 'aging', 'nervous system process',
#        'cytoskeleton-dependent intracellular transport',
#        'extracellular matrix organization', 'chromosome organization',
#        'tRNA metabolic process', 'cellular amino acid metabolic process',
#        'symbiont process', 'mitochondrion organization', 'autophagy',
#        'chromosome segregation', 'mitotic nuclear division',
#        'cell division', 'protein maturation',
#        'cell population proliferation',
#        'protein-containing complex assembly', 'protein transport',
#        'carbohydrate metabolic process',
#        'generation of precursor metabolites and energy',
#        'cell junction organization', 'DNA metabolic process',
#        'biological process involved in symbiotic interaction'],
#       dtype=object)

# %%
biological_process_gos
# Out:
#                                                      mm  mmcasteij  mmpwkphj  \
# cell differentiation                                604        361       335
# biosynthetic process                                485        324       315
# signal transduction                                 421        299       261
# anatomical structure development                    616        397       372
# cellular nitrogen compound metabolic process        389        320       295
# ...                                                 ...        ...       ...
# carbohydrate metabolic process                      269          0         0
# generation of precursor metabolites and energy      232          0         0
# cell junction organization                          321          0         0
# DNA metabolic process                                 0          0         0
# biological process involved in symbiotic intera...   67          0         0
#
#                                                     mmspretus  mmwsbeij  \
# cell differentiation                                      329       349
# biosynthetic process                                      255       325
# signal transduction                                       343       273
# anatomical structure development                          365       383
# cellular nitrogen compound metabolic process              287       313
# ...                                                       ...       ...
# carbohydrate metabolic process                            117         0
# generation of precursor metabolites and energy            117         0
# cell junction organization                                117         0
# DNA metabolic process                                      90         0
# biological process involved in symbiotic intera...          0         0
#
#                                                     mmfvbnj  mmdba2j  \
# cell differentiation                                    343      343
# biosynthetic process                                    325      325
# signal transduction                                     261      261
# anatomical structure development                        393      380
# cellular nitrogen compound metabolic process            313      313
# ...                                                     ...      ...
# carbohydrate metabolic process                            0        0
# generation of precursor metabolites and energy            0        0
# cell junction organization                                0        0
# DNA metabolic process                                     0        0
# biological process involved in symbiotic intera...        0        0
#
#                                                     mm129s1svimj  mmc3hhej  \
# cell differentiation                                         332       343
# biosynthetic process                                         325       325
# signal transduction                                          261       271
# anatomical structure development                             370       380
# cellular nitrogen compound metabolic process                 313       313
# ...                                                          ...       ...
# carbohydrate metabolic process                                 0         0
# generation of precursor metabolites and energy                 0         0
# cell junction organization                                     0         0
# DNA metabolic process                                          0         0
# biological process involved in symbiotic intera...             0         0
#
#                                                     mmnodshiltj  mmbalbcj  \
# cell differentiation                                        339       343
# biosynthetic process                                        319       325
# signal transduction                                         266       261
# anatomical structure development                            367       380
# cellular nitrogen compound metabolic process                305       313
# ...                                                         ...       ...
# carbohydrate metabolic process                                0         0
# generation of precursor metabolites and energy                0         0
# cell junction organization                                    0         0
# DNA metabolic process                                         0         0
# biological process involved in symbiotic intera...            0         0
#
#                                                     mmnzohlltj  mmc57bl6nj  \
# cell differentiation                                       343         343
# biosynthetic process                                       325         325
# signal transduction                                        261         261
# anatomical structure development                           380         380
# cellular nitrogen compound metabolic process               313         313
# ...                                                        ...         ...
# carbohydrate metabolic process                               0           0
# generation of precursor metabolites and energy               0           0
# cell junction organization                                   0           0
# DNA metabolic process                                        0           0
# biological process involved in symbiotic intera...           0           0
#
#                                                     mmcbaj  mmaj  mmakrj  \
# cell differentiation                                   340   343     343
# biosynthetic process                                   325   325     325
# signal transduction                                    261   261     261
# anatomical structure development                       377   371     380
# cellular nitrogen compound metabolic process           309   305     313
# ...                                                    ...   ...     ...
# carbohydrate metabolic process                           0     0       0
# generation of precursor metabolites and energy           0     0       0
# cell junction organization                               0     0       0
# DNA metabolic process                                    0     0       0
# biological process involved in symbiotic intera...       0     0       0
#
#                                                     mmlpj
# cell differentiation                                  343
# biosynthetic process                                  325
# signal transduction                                   261
# anatomical structure development                      380
# cellular nitrogen compound metabolic process          313
# ...                                                   ...
# carbohydrate metabolic process                          0
# generation of precursor metabolites and energy          0
# cell junction organization                              0
# DNA metabolic process                                   0
# biological process involved in symbiotic intera...      0
#
# [64 rows x 17 columns]

# %%
sns.set(font_scale=4)
fig=sns.clustermap(biological_process_gos.T,
                   cmap='flare',
                   figsize=(55,38),
                  tree_kws=dict(linewidths=2.5))
fig.ax_cbar.set_position([0.115, 0.45, 0.02, 0.2])
fig.ax_cbar.set_title('Number of\nGO terms')
fig.ax_cbar.tick_params(axis='y', length=10)
fig.ax_heatmap.set_xticks(np.arange(0.5,len(biological_process_gos.index.values),1))
fig.ax_heatmap.set_xticklabels(biological_process_gos.index.values)
fig.ax_heatmap.set_xlabel('GO slim terms')
fig.ax_heatmap.set_ylabel('Strains')
fig.savefig('../results/biological_process_go.png',dpi=80)

# %%
sns.set(font_scale=4)
fig=sns.clustermap(cellular_component_gos.T,
                   cmap='flare',
                   figsize=(50,28),
                  tree_kws=dict(linewidths=2.5))
fig.ax_cbar.set_position([0.115, 0.45, 0.02, 0.2])
fig.ax_cbar.set_title('Number of\nGO terms')
fig.ax_cbar.tick_params(axis='y', length=10)
fig.ax_heatmap.set_xlabel('GO slim terms')
fig.ax_heatmap.set_ylabel('Strains')
fig.savefig('../results/cellular_component_go.png',dpi=80)

# %%
sns.set(font_scale=4)
fig=sns.clustermap(molecular_function_gos.T,
                   cmap='flare',
                   figsize=(50,38),
                  tree_kws=dict(linewidths=2.5))
fig.ax_cbar.set_position([0.1, 0.55, 0.02, 0.2])
fig.ax_cbar.set_title('Number of\nGO terms')
fig.ax_cbar.tick_params(axis='y', length=10)
fig.ax_heatmap.set_xlabel('GO slim terms')
fig.ax_heatmap.set_ylabel('Strains')
fig.savefig('../results/molecular_function_go.png',dpi=80)
